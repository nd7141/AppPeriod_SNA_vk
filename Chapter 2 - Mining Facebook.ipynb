# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool

ACCESS_TOKEN = 'CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD'

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,friends.fields(likes)'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print url

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print json.dumps(content, indent=1)
# Out:
# https://graph.facebook.com/me?fields=id,name,friends.fields(likes)&access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD
# {
#  "friends": {
#   "paging": {
#    "next": "https://graph.facebook.com/v1.0/1503122313244070/friends?fields=likes&access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=5000&offset=5000&__after_id=enc_Aex3PCNR0Nk8Zb28eGB5VCX4BJMLoY3373Mlow2vd4e778YqIvFrRlvVrRWrn5rMxX9S3tAwcTJkFiDltAJtKlU1"
#   },
#   "data": [
#    {
#     "id": "719348848",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "NjM0MzQ1NTE2NjA5MzY4",
#        "before": "ODA0OTMzNzMyODYyMTQ4"
#       },
#       "next": "https://graph.facebook.com/v1.0/719348848/likes?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=25&after=NjM0MzQ1NTE2NjA5MzY4"
#      },
#      "data": [
#       {
#        "category": "Media/news/publishing",
#        "created_time": "2014-10-11T21:22:28+0000",
#        "name": "Syg.ma",
#        "id": "804933732862148"
#       },
#       {
#        "category": "News/media website",
#        "created_time": "2014-10-07T21:01:31+0000",
#        "name": "Meduza Project",
#        "id": "375587425929352"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2014-10-07T17:02:27+0000",
#        "name": "\u041a\u043e\u043c\u0438\u0442\u0435\u0442 \u0433\u0440\u0430\u0436\u0434\u0430\u043d\u0441\u043a\u0438\u0445 \u0438\u043d\u0438\u0446\u0438\u0430\u0442\u0438\u0432",
#        "id": "211732725598447"
#       },
#       {
#        "category": "Internet/software",
#        "created_time": "2014-10-02T22:43:11+0000",
#        "name": "IO",
#        "category_list": [
#         {
#          "id": "165679780146824",
#          "name": "Food & Restaurant"
#         },
#         {
#          "id": "358483060859947",
#          "name": "Startup"
#         }
#        ],
#        "id": "795052333880052"
#       },
#       {
#        "category": "Magazine",
#        "created_time": "2014-09-27T18:07:59+0000",
#        "name": "\u0421\u043e\u0440\u043e\u043a \u0434\u0432\u0430",
#        "category_list": [
#         {
#          "id": "128232937246338",
#          "name": "Travel & Transportation"
#         }
#        ],
#        "id": "570881243017406"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2014-09-25T13:58:19+0000",
#        "name": "Gaidar Foundation - \u0424\u043e\u043d\u0434 \u0415\u0433\u043e\u0440\u0430 \u0413\u0430\u0439\u0434\u0430\u0440\u0430",
#        "category_list": [
#         {
#          "id": "2603",
#          "name": "Non-Profit Organization"
#         }
#        ],
#        "id": "174472589266834"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-09-22T17:01:51+0000",
#        "name": "Holoscendence",
#        "id": "1376610652628508"
#       },
#       {
#        "category": "Restaurant/cafe",
#        "created_time": "2014-09-22T10:31:37+0000",
#        "name": "\u043a\u043e\u0444\u0435\u0439\u043d\u044b\u0439 \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432 \u00ab\u0427\u0451\u0440\u043d\u044b\u0439\u00bb",
#        "category_list": [
#         {
#          "id": "128673187201735",
#          "name": "Coffee Shop"
#         }
#        ],
#        "id": "268833693257464"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2014-09-17T20:43:56+0000",
#        "name": "Duran",
#        "id": "318130841535190"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-09-11T08:48:49+0000",
#        "name": "Deep Fried Friends",
#        "id": "444985215608648"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-09-01T12:28:08+0000",
#        "name": "\u041f\u0435\u0440\u0441\u043e\u043d\u0430\u043b\u0438\u0437\u0430\u0446\u0438\u044f",
#        "id": "599409233508505"
#       },
#       {
#        "category": "Education",
#        "created_time": "2014-08-30T20:54:28+0000",
#        "name": "\u0428\u043a\u043e\u043b\u0430 \u0443\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u044f \u043f\u0440\u043e\u0434\u0443\u043a\u0442\u0430\u043c\u0438",
#        "id": "891678514193988"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-08-08T14:06:53+0000",
#        "name": "Gipis",
#        "id": "181344975227253"
#       },
#       {
#        "category": "Consulting/business services",
#        "created_time": "2014-08-08T10:37:54+0000",
#        "name": "Leo Burnett Moscow",
#        "category_list": [
#         {
#          "id": "164886566892249",
#          "name": "Advertising Agency"
#         }
#        ],
#        "id": "403425815832"
#       },
#       {
#        "category": "Education",
#        "created_time": "2014-07-14T11:03:51+0000",
#        "name": "Stepic in Russian",
#        "id": "810749762282316"
#       },
#       {
#        "category": "Company",
#        "created_time": "2014-07-09T11:24:37+0000",
#        "name": "Cirqle",
#        "id": "225227274336162"
#       },
#       {
#        "category": "Teacher",
#        "created_time": "2014-05-22T21:28:22+0000",
#        "name": "Ram Dass, Love Serve Remember",
#        "id": "129480070417400"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-05-13T18:44:02+0000",
#        "name": "\u0413\u043b\u0430\u0437\u0430\u0440\u0438\u0439 \u044f\u0437\u044b\u043a\u0430",
#        "id": "637707089655061"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-04-30T14:00:54+0000",
#        "name": "\u041f\u043e\u0440\u0442\u0440\u0435\u0442\u044b \u041f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433\u0430",
#        "id": "662953197074230"
#       },
#       {
#        "category": "Company",
#        "created_time": "2014-04-29T13:27:36+0000",
#        "name": "Production Type",
#        "id": "219037244962074"
#       },
#       {
#        "category": "Science website",
#        "created_time": "2014-04-13T18:13:32+0000",
#        "name": "Experiment",
#        "id": "205456016188497"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-04-11T06:55:21+0000",
#        "name": "\u0416\u0438\u0442\u044c \u0438\u043d\u0442\u0435\u0440\u0435\u0441\u043d\u043e",
#        "id": "401962789930549"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-04-01T18:34:49+0000",
#        "name": "Random",
#        "id": "618960174838942"
#       },
#       {
#        "category": "Magazine",
#        "created_time": "2014-03-25T12:39:30+0000",
#        "name": "Eros and Kosmos",
#        "id": "547442568686432"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-03-23T17:55:08+0000",
#        "name": "Reporter",
#        "id": "634345516609368"
#       }
#      ]
#     }
#    },
#    {
#     "id": "725112359",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTczMDMzMzYyOTA4MDA5",
#        "before": "NTQzMDc5MTQyNDExNzIy"
#       },
#       "next": "https://graph.facebook.com/v1.0/725112359/likes?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=25&after=MTczMDMzMzYyOTA4MDA5"
#      },
#      "data": [
#       {
#        "category": "Organization",
#        "created_time": "2014-10-17T17:50:57+0000",
#        "name": "Web and Coding Club, IIT Bombay",
#        "category_list": [
#         {
#          "id": "200154933429705",
#          "name": "Web Development"
#         },
#         {
#          "id": "152880021441864",
#          "name": "Community Organization"
#         }
#        ],
#        "id": "543079142411722"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2014-10-16T05:31:56+0000",
#        "name": "Synergy Thinking",
#        "id": "720995461308867"
#       },
#       {
#        "category": "Internet/software",
#        "created_time": "2014-10-08T16:22:20+0000",
#        "name": "TalentPad",
#        "id": "1496124530631629"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-10-06T20:28:48+0000",
#        "name": "POPL 2015 Student Group",
#        "id": "753701551342541"
#       },
#       {
#        "category": "Bank/financial services",
#        "created_time": "2014-10-05T18:43:32+0000",
#        "name": "MIT Federal Credit Union",
#        "category_list": [
#         {
#          "id": "211381282212118",
#          "name": "Financial Planning"
#         },
#         {
#          "id": "128184253916402",
#          "name": "Loans"
#         }
#        ],
#        "id": "25738334201"
#       },
#       {
#        "category": "Company",
#        "created_time": "2014-09-27T19:53:18+0000",
#        "name": "Intern For A Day",
#        "id": "699340326812936"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-09-27T18:17:17+0000",
#        "name": "Chase Freedom",
#        "id": "146806477554"
#       },
#       {
#        "category": "Travel/leisure",
#        "created_time": "2014-09-22T03:00:03+0000",
#        "name": "Smarking Inc.",
#        "id": "585073488214336"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-09-20T06:42:42+0000",
#        "name": "Republicans",
#        "id": "203406028962"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-09-20T06:41:47+0000",
#        "name": "GLBT at MIT (G@MIT)",
#        "category_list": [
#         {
#          "id": "198503866828628",
#          "name": "Organization"
#         }
#        ],
#        "id": "250735341706761"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-09-08T04:59:07+0000",
#        "name": "Chase Sapphire",
#        "id": "114777185238548"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-09-06T04:03:22+0000",
#        "name": "MIT Ashdown House",
#        "category_list": [
#         {
#          "id": "165665860162999",
#          "name": "Dorm"
#         }
#        ],
#        "id": "597126410338256"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-08-23T22:48:01+0000",
#        "name": "LikeIt App",
#        "id": "781143365241851"
#       },
#       {
#        "category": "Arts/entertainment/nightlife",
#        "created_time": "2014-08-09T22:44:17+0000",
#        "name": "Bootie SF",
#        "category_list": [
#         {
#          "id": "133436743388217",
#          "name": "Arts & Entertainment"
#         },
#         {
#          "id": "191478144212980",
#          "name": "Night Club"
#         }
#        ],
#        "id": "215145375181715"
#       },
#       {
#        "category": "Website",
#        "created_time": "2014-08-09T22:41:02+0000",
#        "name": "Firsthandfood",
#        "id": "294585257338153"
#       },
#       {
#        "category": "Restaurant/cafe",
#        "created_time": "2014-07-30T20:53:24+0000",
#        "name": "Ike's",
#        "category_list": [
#         {
#          "id": "188296324525457",
#          "name": "Sandwich Shop"
#         }
#        ],
#        "id": "83296120415"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-07-29T00:38:45+0000",
#        "name": "Web Summit",
#        "id": "294067420659309"
#       },
#       {
#        "category": "Internet/software",
#        "created_time": "2014-07-08T22:10:01+0000",
#        "name": "Yelp Engineering",
#        "category_list": [
#         {
#          "id": "2256",
#          "name": "Internet/Software"
#         }
#        ],
#        "id": "392764084098154"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-06-30T08:08:42+0000",
#        "name": "Robinhood",
#        "category_list": [
#         {
#          "id": "2301",
#          "name": "App Page"
#         }
#        ],
#        "id": "440506706037677"
#       },
#       {
#        "category": "Health/medical/pharmacy",
#        "created_time": "2014-06-28T17:07:26+0000",
#        "name": "Ekilibrium Salud Natural",
#        "category_list": [
#         {
#          "id": "357645644269220",
#          "name": "Alternative & Holistic Health"
#         }
#        ],
#        "id": "1453263061575448"
#       },
#       {
#        "category": "Arts/entertainment/nightlife",
#        "created_time": "2014-06-28T16:59:06+0000",
#        "name": "Real Escape Game",
#        "category_list": [
#         {
#          "id": "133436743388217",
#          "name": "Arts & Entertainment"
#         },
#         {
#          "id": "192119584190796",
#          "name": "Event"
#         }
#        ],
#        "id": "321050364592152"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2014-06-26T06:53:04+0000",
#        "name": "Real Escape Room",
#        "category_list": [
#         {
#          "id": "192119584190796",
#          "name": "Event"
#         },
#         {
#          "id": "210881938937928",
#          "name": "Performance Venue"
#         }
#        ],
#        "id": "506310896068671"
#       },
#       {
#        "category": "City",
#        "created_time": "2014-06-09T13:37:00+0000",
#        "name": "San Francisco, California",
#        "category_list": [
#         {
#          "id": "224455390913969",
#          "name": "City"
#         }
#        ],
#        "id": "114952118516947"
#       },
#       {
#        "category": "School",
#        "created_time": "2014-06-06T22:18:32+0000",
#        "name": "KV ONGC Dehradun",
#        "id": "515140838592315"
#       },
#       {
#        "category": "Small business",
#        "created_time": "2014-06-02T06:28:49+0000",
#        "name": "One Tesla: DIY Singing Tesla Coil Kits",
#        "category_list": [
#         {
#          "id": "163197293733225",
#          "name": "Educational Supplies"
#         },
#         {
#          "id": "183430408363083",
#          "name": "Electronic Equipment Service"
#         }
#        ],
#        "id": "173033362908009"
#       }
#      ]
#     }
#    },
#    {
#     "id": "1158068181",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MzQ5NTc3ODI1MTAxMjUz",
#        "before": "MzA1MTE1NzczODcw"
#       },
#       "next": "https://graph.facebook.com/v1.0/1158068181/likes?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=25&after=MzQ5NTc3ODI1MTAxMjUz"
#      },
#      "data": [
#       {
#        "category": "Product/service",
#        "created_time": "2014-10-16T18:57:34+0000",
#        "name": "Adobe",
#        "id": "305115773870"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-10-16T00:54:14+0000",
#        "name": "Websense",
#        "id": "49774380515"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2014-10-16T00:53:45+0000",
#        "name": "Infosecurity Europe",
#        "id": "140827169291068"
#       },
#       {
#        "category": "Media/news/publishing",
#        "created_time": "2014-10-16T00:53:42+0000",
#        "name": "Infosecurity Magazine",
#        "id": "210560332330063"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-10-14T20:31:14+0000",
#        "name": "Sia",
#        "id": "10959868407"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-10-13T04:41:17+0000",
#        "name": "Jassy sekhon",
#        "category_list": [
#         {
#          "id": "1202",
#          "name": "Musician/Band"
#         }
#        ],
#        "id": "797377790313404"
#       },
#       {
#        "category": "Entertainer",
#        "created_time": "2014-10-09T12:18:02+0000",
#        "name": "Smoothini the Ghetto Houdini",
#        "id": "36409337186"
#       },
#       {
#        "category": "Government organization",
#        "created_time": "2014-10-09T06:43:38+0000",
#        "name": "NASA Scientific and Technical Information (STI) Program",
#        "id": "227576127339868"
#       },
#       {
#        "category": "Government organization",
#        "created_time": "2014-10-09T06:39:19+0000",
#        "name": "International Space Station",
#        "id": "168170833215856"
#       },
#       {
#        "category": "Aerospace/defense",
#        "created_time": "2014-10-09T06:39:13+0000",
#        "name": "NASA\u2019s Orion Spacecraft",
#        "category_list": [
#         {
#          "id": "161422927240513",
#          "name": "Government Organization"
#         }
#        ],
#        "id": "129562970446777"
#       },
#       {
#        "category": "Company",
#        "created_time": "2014-10-08T09:38:12+0000",
#        "name": "Diversity - Not Just Photography",
#        "category_list": [
#         {
#          "id": "181475575221097",
#          "name": "Photographer"
#         }
#        ],
#        "id": "305677292875970"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-10-02T16:51:16+0000",
#        "name": "Sham Idrees",
#        "id": "245786235432909"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-09-28T20:51:55+0000",
#        "name": "Sohawa Welfare Society - Sohawa",
#        "id": "678550552240676"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2014-09-25T20:56:38+0000",
#        "name": "Just Baskets PK",
#        "category_list": [
#         {
#          "id": "176831012360626",
#          "name": "Professional Services"
#         }
#        ],
#        "id": "1478574339076782"
#       },
#       {
#        "category": "Artist",
#        "created_time": "2014-09-17T09:36:41+0000",
#        "name": "Parineeti Chopra",
#        "id": "301358363354984"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-09-10T20:51:29+0000",
#        "name": "Adele",
#        "id": "9770929278"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-09-10T20:30:29+0000",
#        "name": "Carly Rose Sonenclar",
#        "id": "135342545965"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-09-10T15:27:00+0000",
#        "name": "Stopover Pakistan",
#        "id": "494702007251299"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2014-09-10T13:26:07+0000",
#        "name": "Code Decode",
#        "id": "372078579541100"
#       },
#       {
#        "category": "Politician",
#        "created_time": "2014-09-02T00:10:26+0000",
#        "name": "Syed Faisal Raza Abidi",
#        "id": "139684631375"
#       },
#       {
#        "category": "Athlete",
#        "created_time": "2014-08-21T22:20:23+0000",
#        "name": "Bastian Schweinsteiger",
#        "id": "7991759722"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2014-08-21T20:51:50+0000",
#        "name": "Tom Cruise",
#        "id": "81512169979"
#       },
#       {
#        "category": "Athlete",
#        "created_time": "2014-08-21T20:12:57+0000",
#        "name": "Didier Drogba",
#        "id": "476609922465576"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-08-21T19:40:07+0000",
#        "name": "LikeIt App",
#        "id": "781143365241851"
#       },
#       {
#        "category": "Athlete",
#        "created_time": "2014-08-21T18:50:25+0000",
#        "name": "Petr \u010cech",
#        "id": "349577825101253"
#       }
#      ]
#     }
#    },
#    {
#     "id": "10203921682750410",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "Mzk4OTE4NjMwMjA4MTU0",
#        "before": "MTM3MjU0NzQ5NjI5MjQ4"
#       },
#       "next": "https://graph.facebook.com/v1.0/10203921682750410/likes?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=25&after=Mzk4OTE4NjMwMjA4MTU0"
#      },
#      "data": [
#       {
#        "category": "Electronics",
#        "created_time": "2014-10-20T14:20:56+0000",
#        "name": "Nokia \u0420\u043e\u0441\u0441\u0438\u044f",
#        "id": "137254749629248"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2014-10-17T10:47:53+0000",
#        "name": "Slush",
#        "id": "240966039259839"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-10-16T09:12:41+0000",
#        "name": "MIT 100K Entrepreneurship Competition",
#        "category_list": [
#         {
#          "id": "198503866828628",
#          "name": "Organization"
#         }
#        ],
#        "id": "35546482165"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-10-13T14:03:21+0000",
#        "name": "Skolkovo Robotics Center",
#        "id": "579802935481171"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-10-08T05:45:13+0000",
#        "name": "Be traveling \u041e\u0442\u043a\u0440\u044b\u0442\u0438\u044f \u0421\u043e\u0431\u044b\u0442\u0438\u044f \u041f\u0440\u0438\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u044f",
#        "id": "395612573873624"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-10-01T16:55:11+0000",
#        "name": "Anatomy Studies for Yoga Teachers & Movement Professionals",
#        "id": "136083849750132"
#       },
#       {
#        "category": "Software",
#        "created_time": "2014-10-01T16:54:52+0000",
#        "name": "Yoga Functional Anatomy",
#        "id": "245923222129218"
#       },
#       {
#        "category": "Internet/software",
#        "created_time": "2014-09-28T07:00:04+0000",
#        "name": "CreativePeople",
#        "category_list": [
#         {
#          "id": "200154933429705",
#          "name": "Web Development"
#         },
#         {
#          "id": "164886566892249",
#          "name": "Advertising Agency"
#         }
#        ],
#        "id": "120981607930174"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2014-09-28T06:59:49+0000",
#        "name": "Readymag",
#        "id": "273982909334179"
#       },
#       {
#        "category": "Concert venue",
#        "created_time": "2014-09-26T06:50:15+0000",
#        "name": "\u041d\u043e\u0447\u044c \u043c\u0443\u0437\u044b\u043a\u0438",
#        "category_list": [
#         {
#          "id": "192119584190796",
#          "name": "Event"
#         },
#         {
#          "id": "180164648685982",
#          "name": "Bands & Musicians"
#         },
#         {
#          "id": "179943432047564",
#          "name": "Concert Venue"
#         }
#        ],
#        "id": "509574242469731"
#       },
#       {
#        "category": "Arts/entertainment/nightlife",
#        "created_time": "2014-08-28T14:43:06+0000",
#        "name": "Powerhouse Moscow",
#        "category_list": [
#         {
#          "id": "110290705711626",
#          "name": "Bar"
#         },
#         {
#          "id": "273819889375819",
#          "name": "Restaurant"
#         },
#         {
#          "id": "189483194405517",
#          "name": "Music Production"
#         }
#        ],
#        "id": "592823174093990"
#       },
#       {
#        "category": "Website",
#        "created_time": "2014-08-28T07:09:06+0000",
#        "name": "\u0416\u0443\u0440\u043d\u0430\u043b \"\u041c\u0430\u0440\u0430\u0444\u043e\u043d\u0435\u0446\"",
#        "id": "267089133480024"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-08-25T08:19:42+0000",
#        "name": "LikeIt App",
#        "id": "781143365241851"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-08-10T15:45:08+0000",
#        "name": "Hipsta Mama",
#        "id": "662180520482530"
#       },
#       {
#        "category": "Food/beverages",
#        "created_time": "2014-07-21T16:46:52+0000",
#        "name": "Organic Religion",
#        "category_list": [
#         {
#          "id": "2252",
#          "name": "Food/Beverages"
#         }
#        ],
#        "id": "477701082362755"
#       },
#       {
#        "category": "Travel/leisure",
#        "created_time": "2014-07-19T09:52:05+0000",
#        "name": "Unity Run Camp",
#        "id": "512404688825164"
#       },
#       {
#        "category": "Wine/spirits",
#        "created_time": "2014-06-23T10:41:01+0000",
#        "name": "Vinarija Ma\u0161anovi\u0107 - Winery Masanovic, Montenegro",
#        "id": "126009477483673"
#       },
#       {
#        "category": "Jewelry/watches",
#        "created_time": "2014-05-27T11:26:01+0000",
#        "name": "\u0421\u0430\u0445\u0430\u0440\u043e\u043a",
#        "id": "298710193617659"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-05-26T09:04:51+0000",
#        "name": "21runners Club",
#        "id": "241951059298023"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2014-04-24T06:37:42+0000",
#        "name": "Board of European Students of Technology",
#        "id": "164025103628518"
#       },
#       {
#        "category": "Electronics",
#        "created_time": "2014-04-18T10:39:26+0000",
#        "name": "Madrobots",
#        "id": "125198440983807"
#       },
#       {
#        "category": "Jewelry/watches",
#        "created_time": "2014-04-09T06:24:47+0000",
#        "name": "WHITE white Rabbit",
#        "id": "268952013284910"
#       },
#       {
#        "category": "Food/grocery",
#        "created_time": "2014-03-29T09:19:05+0000",
#        "name": "Leafy Greens Salad Bar",
#        "category_list": [
#         {
#          "id": "200742186618963",
#          "name": "Vegetarian & Vegan Restaurant"
#         },
#         {
#          "id": "112286315572975",
#          "name": "Salad Bar"
#         },
#         {
#          "id": "176007949109829",
#          "name": "Buffet Restaurant"
#         }
#        ],
#        "id": "263347427092258"
#       },
#       {
#        "category": "Athlete",
#        "created_time": "2014-03-23T19:21:52+0000",
#        "name": "Vegan Bodybuilding",
#        "id": "156051797771528"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2014-03-23T06:41:30+0000",
#        "name": "C Programming codes",
#        "id": "398918630208154"
#       }
#      ]
#     }
#    },
#    {
#     "id": "100000012703036",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTE5ODc2ODM3NzY1",
#        "before": "MTQzMTUwNjU1Mzc4NjY2NA=="
#       }
#      },
#      "data": [
#       {
#        "category": "Cause",
#        "created_time": "2014-09-23T22:03:50+0000",
#        "name": "Your sector of space - \u0422\u0432\u043e\u0439 \u0441\u0435\u043a\u0442\u043e\u0440 \u043a\u043e\u0441\u043c\u043e\u0441\u0430",
#        "id": "1431506553786664"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-09-01T22:45:33+0000",
#        "name": "Aeronautics Interest Group",
#        "id": "480033298800417"
#       },
#       {
#        "category": "Cars",
#        "created_time": "2014-08-22T10:07:22+0000",
#        "name": "Hyundai Russia",
#        "id": "161792303832409"
#       },
#       {
#        "category": "Bar",
#        "created_time": "2014-08-11T22:47:53+0000",
#        "name": "Xception It Loft",
#        "category_list": [
#         {
#          "id": "162480900474637",
#          "name": "Dive Bar"
#         }
#        ],
#        "id": "336792639819120"
#       },
#       {
#        "category": "Computers",
#        "created_time": "2013-09-02T21:46:57+0000",
#        "name": "System76",
#        "id": "38123997728"
#       },
#       {
#        "category": "University",
#        "created_time": "2013-08-21T17:08:49+0000",
#        "name": "<\u0444\u0430\u0431\u043b\u0430\u0431>",
#        "id": "284542358300660"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2012-11-28T03:58:15+0000",
#        "name": "The School of Science, HKUST",
#        "id": "107773938780"
#       },
#       {
#        "category": "Website",
#        "created_time": "2012-10-12T14:55:29+0000",
#        "name": "\u00ab\u041e\u0431\u043b\u0430\u043a\u0430 2012\u00bb: \u042f \u0433\u043e\u043b\u043e\u0441\u0443\u044e \u0437\u0430 'Juplin'",
#        "id": "412821278771399"
#       },
#       {
#        "category": "University",
#        "created_time": "2012-08-02T22:07:13+0000",
#        "name": "Skolkovo Institute of Science and Technology",
#        "category_list": [
#         {
#          "id": "108051929285833",
#          "name": "College & University"
#         }
#        ],
#        "id": "219605978125334"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2012-05-08T10:41:43+0000",
#        "name": "\"IPad-kiosk & iPad-stand & iPad-enclosure\"",
#        "id": "271849092912082"
#       },
#       {
#        "category": "Software",
#        "created_time": "2012-04-18T13:18:36+0000",
#        "name": "Around The World - Free Offline Android Maps",
#        "id": "165208820237686"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2012-02-27T05:48:26+0000",
#        "name": "Buyincoins  fans",
#        "id": "270435439688054"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2012-01-17T10:21:45+0000",
#        "name": "\u0444\u043e\u043d \u0428\u0442\u0435\u0444\u0430\u043d\u0438\u0446",
#        "id": "157820957595173"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2011-11-09T12:13:06+0000",
#        "name": "Cerebelo",
#        "id": "283641741669125"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2011-09-23T12:46:05+0000",
#        "name": "Wholesale ~~ARM DSO Nano dso203   Pocket Sized Digital Oscilloscope with TFT LCD Module",
#        "id": "151906148236644"
#       },
#       {
#        "category": "Community",
#        "created_time": "2011-01-31T12:55:35+0000",
#        "name": "motoshkola.spb.ru",
#        "id": "133059366751777"
#       },
#       {
#        "category": "Interest",
#        "created_time": "2010-08-27T08:25:16+0000",
#        "name": "Chaos Constructions'2010",
#        "id": "153921827954648"
#       },
#       {
#        "category": "Website",
#        "created_time": "2010-02-10T21:03:51+0000",
#        "name": "Translate.Ru",
#        "id": "477671035256"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2009-09-15T15:01:44+0000",
#        "name": "\u041a\u043e\u043c\u0430\u043d\u0434\u0430 \u041d\u041e",
#        "id": "119876837765"
#       }
#      ]
#     }
#    },
#    {
#     "id": "100000841654146",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTQwMjY1NTM0MjM5",
#        "before": "MTU3NDExMDY0MjgxMDkyMw=="
#       },
#       "next": "https://graph.facebook.com/v1.0/100000841654146/likes?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=25&after=MTQwMjY1NTM0MjM5"
#      },
#      "data": [
#       {
#        "category": "Education",
#        "created_time": "2014-10-04T13:57:28+0000",
#        "name": "Peter Douglas Tutoring",
#        "category_list": [
#         {
#          "id": "145296352197250",
#          "name": "Tutoring"
#         }
#        ],
#        "id": "1574110642810923"
#       },
#       {
#        "category": "Artist",
#        "created_time": "2014-09-28T23:03:41+0000",
#        "name": "Yi-Jia Susanne Hou",
#        "id": "358159614359877"
#       },
#       {
#        "category": "Phone/tablet",
#        "created_time": "2014-09-10T14:41:51+0000",
#        "name": "MyiPhone6case.com",
#        "id": "1460722910868304"
#       },
#       {
#        "category": "Food/beverages",
#        "created_time": "2014-07-17T20:19:15+0000",
#        "name": "Hisabo Tea Collection",
#        "id": "242564035932764"
#       },
#       {
#        "category": "Radio station",
#        "created_time": "2014-06-24T01:21:21+0000",
#        "name": "Meet the Composer",
#        "id": "306827616150517"
#       },
#       {
#        "category": "Education",
#        "created_time": "2014-06-23T18:52:09+0000",
#        "name": "\u4e16\u754c\u306b\u7fbd\u3070\u305f\u304f\u30cd\u30a4\u30c6\u30a3\u30d6\u8133\u3092\u80b2\u3066\u3088\u3046",
#        "id": "258496814302184"
#       },
#       {
#        "category": "Media/news/publishing",
#        "created_time": "2014-06-19T19:53:48+0000",
#        "name": "Creative Drive Media",
#        "id": "531550623556308"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2014-06-17T12:57:03+0000",
#        "name": "Boyar Music Studios",
#        "category_list": [
#         {
#          "id": "186983191324114",
#          "name": "Music Lessons & Instruction"
#         },
#         {
#          "id": "189483194405517",
#          "name": "Music Production"
#         },
#         {
#          "id": "191684877517919",
#          "name": "Publisher"
#         }
#        ],
#        "id": "437286596389677"
#       },
#       {
#        "category": "Company",
#        "created_time": "2014-05-31T01:03:54+0000",
#        "name": "Belleds",
#        "id": "249896248526892"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2014-05-20T22:37:15+0000",
#        "name": "Ronnie O'Sullivan",
#        "id": "109361512423166"
#       },
#       {
#        "category": "Author",
#        "created_time": "2014-05-19T22:15:53+0000",
#        "name": "Leo Tolstoy",
#        "id": "339284532763832"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-05-02T03:48:10+0000",
#        "name": "Dan Tepfer",
#        "id": "164355976955508"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-04-26T18:24:10+0000",
#        "name": "Saeunn Thorsteinsdottir",
#        "id": "266137626890915"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2014-04-20T23:28:46+0000",
#        "name": "Christopher Falzone's  International FanClub",
#        "id": "208413605903496"
#       },
#       {
#        "category": "Kitchen/cooking",
#        "created_time": "2014-03-21T01:51:25+0000",
#        "name": "Grin And Eat",
#        "id": "440031486130603"
#       },
#       {
#        "category": "Real estate",
#        "created_time": "2014-03-20T18:34:57+0000",
#        "name": "Donna Moore Properties",
#        "category_list": [
#         {
#          "id": "198327773511962",
#          "name": "Real Estate"
#         }
#        ],
#        "id": "202865953133024"
#       },
#       {
#        "category": "Internet/software",
#        "created_time": "2014-03-12T16:31:29+0000",
#        "name": "Trill",
#        "id": "350236078453164"
#       },
#       {
#        "category": "App page",
#        "created_time": "2014-03-03T21:51:50+0000",
#        "name": "GroupTally",
#        "id": "164726050395566"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-02-26T16:53:54+0000",
#        "name": "\u041a\u0430\u043a \u0441\u0442\u0430\u0442\u044c \u0431\u043e\u0433\u0430\u0447\u0435. \u041f\u0440\u0438 \u043f\u043e\u0434\u0434\u0435\u0440\u0436\u043a\u0435 \u041d\u0418\u0423 \u0412\u0428\u042d \u0438 QIWI",
#        "id": "623361751052862"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-02-01T02:10:21+0000",
#        "name": "MIT Sloan Entrepreneurship and Innovation Club",
#        "id": "196504380402908"
#       },
#       {
#        "category": "Education",
#        "created_time": "2014-01-20T14:16:43+0000",
#        "name": "Learnto",
#        "category_list": [
#         {
#          "id": "187751327923426",
#          "name": "Educational Organization"
#         },
#         {
#          "id": "108557642554592",
#          "name": "Educational Service"
#         }
#        ],
#        "id": "450840571693053"
#       },
#       {
#        "category": "App page",
#        "created_time": "2013-12-12T22:15:30+0000",
#        "name": "Pictual",
#        "id": "643321445709602"
#       },
#       {
#        "category": "Education",
#        "created_time": "2013-12-11T20:34:03+0000",
#        "name": "New Valence Robotics",
#        "category_list": [
#         {
#          "id": "151676848220295",
#          "name": "Education"
#         }
#        ],
#        "id": "445545202232501"
#       },
#       {
#        "category": "Farming/agriculture",
#        "created_time": "2013-12-11T16:44:00+0000",
#        "name": "Grove Labs",
#        "category_list": [
#         {
#          "id": "197289820310880",
#          "name": "Home"
#         },
#         {
#          "id": "150060378385891",
#          "name": "Appliances"
#         }
#        ],
#        "id": "710456582303126"
#       },
#       {
#        "category": "Musical instrument",
#        "created_time": "2013-12-04T20:21:30+0000",
#        "name": "Malletshop.com",
#        "id": "140265534239"
#       }
#      ]
#     }
#    },
#    {
#     "id": "706975609387035"
#    },
#    {
#     "id": "295713787300065",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "NDIwNzUxNDc0NjkwNjMx",
#        "before": "MTQ3ODQ3MjU3NTc1MzY0MQ=="
#       },
#       "next": "https://graph.facebook.com/v1.0/295713787300065/likes?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=25&after=NDIwNzUxNDc0NjkwNjMx"
#      },
#      "data": [
#       {
#        "category": "Community",
#        "created_time": "2014-10-19T08:01:34+0000",
#        "name": "CocoaHeads Moscow",
#        "id": "1478472575753641"
#       },
#       {
#        "category": "Community",
#        "created_time": "2014-10-14T06:51:03+0000",
#        "name": "Skolkovo Robotics Center",
#        "id": "579802935481171"
#       },
#       {
#        "category": "Organization",
#        "created_time": "2014-09-26T10:37:05+0000",
#        "name": "Media Group Inc",
#        "category_list": [
#         {
#          "id": "198503866828628",
#          "name": "Organization"
#         }
#        ],
#        "id": "296032833766015"
#       },
#       {
#        "category": "Education",
#        "created_time": "2014-07-25T12:32:50+0000",
#        "name": "Skoltech Admissions",
#        "id": "594816887275901"
#       },
#       {
#        "category": "Science website",
#        "created_time": "2013-12-18T22:05:29+0000",
#        "name": "\u0426\u0435\u043d\u0442\u0440 \u0438\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u0439 \u043c\u0438\u0433\u0440\u0430\u0446\u0438\u0438 \u0438 \u044d\u0442\u043d\u0438\u0447\u043d\u043e\u0441\u0442\u0438",
#        "id": "643502545682917"
#       },
#       {
#        "category": "Company",
#        "created_time": "2013-05-25T13:10:15+0000",
#        "name": "Airsoft-Militaria.pl",
#        "category_list": [
#         {
#          "id": "2200",
#          "name": "Company"
#         }
#        ],
#        "id": "285829508098376"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2013-05-25T13:09:56+0000",
#        "name": "Zgie\u0142k",
#        "id": "130217310366811"
#       },
#       {
#        "category": "Hotel",
#        "created_time": "2013-05-25T13:03:28+0000",
#        "name": "Palace Apartments Krak\u00f3w - Apartamenty w Krakowie",
#        "id": "168227349882885"
#       },
#       {
#        "category": "Furniture",
#        "created_time": "2013-05-25T13:00:04+0000",
#        "name": "Polskie MEBLE // Polskie Systemy Meblowe W UK",
#        "id": "554249594626587"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-05-25T12:59:26+0000",
#        "name": "Tanio zje\u015b\u0107",
#        "id": "150664031751148"
#       },
#       {
#        "category": "Health/beauty",
#        "created_time": "2013-05-25T12:40:39+0000",
#        "name": "Shadz OnlineShop",
#        "category_list": [
#         {
#          "id": "144873802247220",
#          "name": "Cosmetics & Beauty Supply"
#         }
#        ],
#        "id": "166978416655004"
#       },
#       {
#        "category": "Health/beauty",
#        "created_time": "2013-05-25T12:38:29+0000",
#        "name": "Naturactor Cover Face Concealer - Philippines",
#        "id": "445182802235686"
#       },
#       {
#        "category": "Clothing",
#        "created_time": "2013-05-25T12:09:36+0000",
#        "name": "ZOE & CHLOE Online Boutique",
#        "id": "293622417406995"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2013-05-25T11:11:39+0000",
#        "name": "S.D.",
#        "id": "431819156868176"
#       },
#       {
#        "category": "Legal/law",
#        "created_time": "2013-05-25T11:09:30+0000",
#        "name": "Wynn & Wynn Attorneys P.C.",
#        "category_list": [
#         {
#          "id": "2249",
#          "name": "Legal/Law"
#         }
#        ],
#        "id": "120009524834946"
#       },
#       {
#        "category": "Politician",
#        "created_time": "2013-05-25T10:57:03+0000",
#        "name": "Enrique Ag\u00fcera Ib\u00e1\u00f1ez",
#        "id": "293355037353854"
#       },
#       {
#        "category": "Church/religious organization",
#        "created_time": "2013-05-25T10:50:47+0000",
#        "name": "Zirci Ciszterci Ap\u00e1ts\u00e1g",
#        "category_list": [
#         {
#          "id": "187714557925874",
#          "name": "Religious Organization"
#         }
#        ],
#        "id": "507299389306499"
#       },
#       {
#        "category": "Musician/band",
#        "created_time": "2013-05-25T10:48:03+0000",
#        "name": "Uriel Vega",
#        "id": "153515674785974"
#       },
#       {
#        "category": "Computers/technology",
#        "created_time": "2013-05-25T10:18:46+0000",
#        "name": "Eleno Parts & Service",
#        "category_list": [
#         {
#          "id": "2255",
#          "name": "Computers/Technology"
#         }
#        ],
#        "id": "396653820448235"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2013-05-25T09:28:17+0000",
#        "name": "Adrenaline Motorsports",
#        "id": "194708203875564"
#       },
#       {
#        "category": "Jewelry/watches",
#        "created_time": "2013-05-25T09:26:56+0000",
#        "name": "Rubber B - The Ultimate Rubber Strap",
#        "id": "129078757170083"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2013-05-25T09:17:40+0000",
#        "name": "Weddingdisplays",
#        "id": "408175292589546"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-05-25T09:17:07+0000",
#        "name": "BIG Investment Group LLC",
#        "id": "330911063680848"
#       },
#       {
#        "category": "Politician",
#        "created_time": "2013-05-25T08:56:13+0000",
#        "name": "Pepe El\u00edas Leal",
#        "id": "425080207581725"
#       },
#       {
#        "category": "Home improvement",
#        "created_time": "2013-05-25T07:11:52+0000",
#        "name": "Jeff of All Trades Handyman Service",
#        "id": "420751474690631"
#       }
#      ]
#     }
#    }
#   ]
#  },
#  "id": "1503122313244070",
#  "name": "Sergey Ivanov"
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print json.dumps(o, indent=1)

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print '---------------'
print 'Me'
print '---------------'
pp(g.get_object('me'))
print
print '---------------'
print 'My Friends'
print '---------------'
pp(g.get_connections('me', 'friends'))
print
print '---------------'
print 'Social Web'
print '---------------'
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "first_name": "Sergey",
#  "last_name": "Ivanov",
#  "verified": true,
#  "name": "Sergey Ivanov",
#  "locale": "en_US",
#  "gender": "male",
#  "work": [
#   {
#    "employer": {
#     "id": "219605978125334",
#     "name": "Skolkovo Institute of Science and Technology"
#    }
#   }
#  ],
#  "updated_time": "2014-03-09T15:04:23+0000",
#  "birthday": "11/29/1990",
#  "link": "https://www.facebook.com/profile.php?id=100006389463675",
#  "location": {
#   "id": "115085015172389",
#   "name": "Moscow, Russia"
#  },
#  "timezone": 4,
#  "id": "1503122313244070"
# }
# ---------------
# My Friends
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/1503122313244070/friends?access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=5000&offset=5000&__after_id=enc_AewoeDmpbX71r1usCq-5OJX6KWJXqUW1HL2-yrNBOuJ8EwfLfazaxG0YETkfluthOjpn9bM8LzLIsPOR5FQTckIz"
#  },
#  "data": [
#   {
#    "name": "Gleb Kalinin",
#    "id": "719348848"
#   },
#   {
#    "name": "Rohit Singh",
#    "id": "725112359"
#   },
#   {
#    "name": "Muhammad Saad",
#    "id": "1158068181"
#   },
#   {
#    "name": "Anastasia  Pukalova",
#    "id": "10203921682750410"
#   },
#   {
#    "name": "Oleg Urzhumtsev",
#    "id": "100000012703036"
#   },
#   {
#    "name": "Amanda von Goetz",
#    "id": "100000841654146"
#   },
#   {
#    "name": "Almir Dzhumaev",
#    "id": "706975609387035"
#   },
#   {
#    "name": "Fedor  Chervinskii",
#    "id": "295713787300065"
#   }
#  ]
# }
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/v1.0/search?type=page&q=social+web&access_token=CAACEdEose0cBAKqDWq2OvBzdJHZAZBqdzC29CCvVJMciYM4ijSxUJuQKOIMl8e7uiBmNqYnvvVO7S8h03zMEoeZBU4vwZCNhoGQvIOgjYm3IL7jgfH5fLi8rG9rZCti4lhqytzoxVZAGiikaJvMepDkEBzqI0mpFZCE5IZBmJqvMQSKEJS4yk44Kfpb0rnkYYYcdLfZAwO4oejfZAuofNn82TmZB5ChqWZBaO98ZD&limit=5000&offset=5000&__after_id=enc_Aex0Cebb5_2Vb8N2PDWtgnaHcen6b2pVrblUcaCvUEkYO1bEf42_gI-HelwgbBGQQodbTWxHyVpaho4ZVtiXnkfP"
#  },
#  "data": [
#   {
#    "category": "Local business",
#    "name": "Spider Web Social Media Management",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "819787441388121"
#   },
#   {
#    "category": "Business services",
#    "name": "socialWEB",
#    "category_list": [
#     {
#      "id": "200209719995975",
#      "name": "Business Supply Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "114355558650055"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead senegal",
#    "id": "344899405678326"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialWebMarketing",
#    "id": "226633110719998"
#   },
#   {
#    "category": "Website",
#    "name": "Social Webshop",
#    "id": "1394913830760636"
#   },
#   {
#    "category": "Movie theater",
#    "name": "Social Webshop UK",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "367809806695037"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cafe",
#    "id": "255596497809113"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Website",
#    "id": "210604392401626"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWeb.ro",
#    "id": "185753574790507"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webs",
#    "id": "174735529355893"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Girl",
#    "id": "1425389227704470"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Caroline Webb   Digital & Social Media",
#    "id": "219957014881658"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webforce",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "128172607258182"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "145218172174013"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "181475575221097",
#      "name": "Photographer"
#     }
#    ],
#    "id": "144307838980365"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web Reporter",
#    "id": "598817503529463"
#   },
#   {
#    "category": "Arts/humanities website",
#    "name": "Social Web Art",
#    "id": "833575423359366"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Alliance",
#    "id": "160477007390933"
#   },
#   {
#    "category": "Shopping/retail",
#    "name": "Social webschop",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "856066491099666"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Ranking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "470852336273104"
#   },
#   {
#    "category": "Radio station",
#    "name": "WebRadio Social",
#    "id": "172438649562650"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialWeb",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "669751383086793"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social / Web Marketing Agency - Stir USA | Canada",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "152246029758"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social webs cheats",
#    "id": "227273367442760"
#   },
#   {
#    "category": "Software",
#    "name": "SocialWebshop Poland",
#    "id": "853892051289097"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social",
#    "id": "481173118576926"
#   },
#   {
#    "category": "App page",
#    "name": "SocialWebbie",
#    "id": "217112891701827"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ],
#    "id": "162973743866087"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Nerd",
#    "id": "121955387828900"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Day",
#    "id": "137161799695400"
#   },
#   {
#    "category": "Interest",
#    "name": "Social web",
#    "id": "112879218725926"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "441220109348770"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Tools",
#    "id": "403059893050740"
#   },
#   {
#    "category": "Tv network",
#    "name": "Ceflix social web tv",
#    "id": "760164607375916"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Websoftseo Social",
#    "id": "378379822329057"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web Thing",
#    "id": "114874051893438"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop FR",
#    "id": "235406569990322"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "SOCIAL WEBSITE",
#    "id": "290608457641244"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "103944626326539"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWebOS",
#    "category_list": [
#     {
#      "id": "2703",
#      "name": "Computers/Internet Website"
#     }
#    ],
#    "id": "358524254168284"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Associates",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "327997047315600"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Consulting",
#    "id": "248823435257496"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialWebshops",
#    "id": "648911958521685"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Factory",
#    "id": "67783847861"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Innovation",
#    "id": "162028037196792"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Webmarks",
#    "id": "230470560302996"
#   },
#   {
#    "category": "Product/service",
#    "name": "On The Webb Social Media Services",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "210125749066257"
#   },
#   {
#    "category": "Book",
#    "name": "Mining the Social Web",
#    "id": "146803958708175"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "275989642418291"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social WebNet LLC",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "214860238659493"
#   },
#   {
#    "category": "Musician/band",
#    "name": "WebtonSocial",
#    "id": "151651414881841"
#   },
#   {
#    "category": "Website",
#    "name": "Social WEBsy",
#    "id": "649472268507131"
#   },
#   {
#    "category": "Local business",
#    "name": "Social web design by x10industries",
#    "id": "330043283780"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webology",
#    "id": "199369666770042"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Web Talks",
#    "id": "316613681700247"
#   },
#   {
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1",
#    "id": "419507011456285"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "In Social Web",
#    "id": "168072826666497"
#   },
#   {
#    "category": "Community organization",
#    "name": "Social Web Tech Talk",
#    "id": "173272359544586"
#   },
#   {
#    "category": "Community",
#    "name": "Social Webs",
#    "id": "159735864118250"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social & Web Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "172427156148334"
#   },
#   {
#    "category": "Education",
#    "name": "Social Web Academy",
#    "id": "192046090848741"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social WEB",
#    "id": "644404665577920"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web",
#    "id": "156184496617"
#   },
#   {
#    "category": "Company",
#    "name": "Social web consulting",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "438991686226624"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Dzine",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "122698737762622"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web BREAKFAST",
#    "id": "175318852545291"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web.Search.Social",
#    "id": "214631441934914"
#   },
#   {
#    "category": "Company",
#    "name": "Weber Shandwick Social Impact",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "89444069963"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webshop Italy",
#    "id": "610458242362481"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Websurf Social Media",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "102106206533278"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webfluence Social Media & Internet Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "112879788755706"
#   },
#   {
#    "category": "Concert venue",
#    "name": "SocialWeb",
#    "id": "186493478082456"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Gym",
#    "category_list": [
#     {
#      "id": "185900881450649",
#      "name": "Personal Coaching"
#     }
#    ],
#    "id": "488323237847526"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Genesis Web Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "186129094876663"
#   },
#   {
#    "category": "Website",
#    "name": "Islamic & Social Website - abswerbd.com",
#    "id": "677061112307489"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial",
#    "id": "208290102524008"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Urls",
#    "id": "806157402782310"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Wizard",
#    "id": "169089429771025"
#   },
#   {
#    "category": "Home improvement",
#    "name": "Websites & Social Media",
#    "category_list": [
#     {
#      "id": "108427109235243",
#      "name": "Home Improvement"
#     }
#    ],
#    "id": "213642188759243"
#   },
#   {
#    "category": "Website",
#    "name": "My Social Media Website",
#    "id": "265276823522152"
#   },
#   {
#    "category": "Local business",
#    "name": "etrade.ba | Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "217376194979375"
#   },
#   {
#    "category": "Company",
#    "name": "Hi Fi Social Web",
#    "id": "196298563744277"
#   },
#   {
#    "category": "Community",
#    "name": "Web Social",
#    "id": "231682236924947"
#   },
#   {
#    "category": "Professional services",
#    "name": "WebSpot Social",
#    "id": "175322602545416"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "My Social Web",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ],
#    "id": "76277666156"
#   },
#   {
#    "category": "Organization",
#    "name": "SocialWeb.in",
#    "id": "680577328699377"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social-Webcam",
#    "id": "138187269563360"
#   },
#   {
#    "category": "Community",
#    "name": "Social WEB",
#    "id": "295703510589892"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Communication",
#    "category_list": [
#     {
#      "id": "132008380200065",
#      "name": "Image Consultant"
#     }
#    ],
#    "id": "165807746962152"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Dev",
#    "id": "233682666821223"
#   },
#   {
#    "category": "Company",
#    "name": "Webshoutz be social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "502559819771053"
#   },
#   {
#    "category": "Education",
#    "name": "WebSocial",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "192541364117143"
#   },
#   {
#    "category": "Community organization",
#    "name": "SocialWebConneXion.com",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "152880021441864",
#      "name": "Community Organization"
#     }
#    ],
#    "id": "636570933034875"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Social4Web",
#    "id": "169765039795027"
#   },
#   {
#    "category": "Interest",
#    "name": "Social website",
#    "id": "198566960212311"
#   },
#   {
#    "category": "Community",
#    "name": "Webster Alumni Social Group",
#    "id": "487171701376262"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Promotions",
#    "id": "234335963269949"
#   },
#   {
#    "category": "Local business",
#    "name": "WebSocialTraffic",
#    "id": "19939664284"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Website Designing in Dubai, Website Development,Social Media Marketing-seo",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     }
#    ],
#    "id": "1392517094365062"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Promoter",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "657099161012700"
#   },
#   {
#    "category": "Local business",
#    "name": "Web1 Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "119307778101744"
#   },
#   {
#    "category": "Website",
#    "name": "Social/News/Culture Website",
#    "id": "1450059198607934"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Schreckgespenster Webdesign & Social Media Marketing",
#    "id": "707284739354883"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Leading Logic - Web, Social, Marketing, Design",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "136481676384923"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "The Social Web Company",
#    "id": "460355617439986"
#   },
#   {
#    "category": "Company",
#    "name": "SocialWeb Consulting",
#    "id": "177391935634180"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Web Cafe TV",
#    "id": "149184731910179"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Design",
#    "id": "281249708648873"
#   },
#   {
#    "category": "Business services",
#    "name": "Website Social Media Development",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "522531034450480"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Power",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "835021083188471"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Strategies",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "8387137434"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Milano Social Web",
#    "id": "252633804884736"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media & Websites",
#    "id": "278572212299892"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "118119234870548"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media & Website Solutions by 108 degrees",
#    "id": "125953907477790"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Bee Web Marketing and Design",
#    "id": "187494864706626"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Website Design Tutorials And Social Media Marketing",
#    "id": "418218642781"
#   },
#   {
#    "category": "Artist",
#    "name": "Ion Gonzaga, The Social Web Designer",
#    "id": "120679007979099"
#   },
#   {
#    "category": "Local business",
#    "name": "Ed Doherty Jr. - SEO, Social, Web Design",
#    "id": "519084648117730"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Impact Web",
#    "id": "196321800413834"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web/Social Marketing",
#    "id": "172670552803004"
#   },
#   {
#    "category": "Local business",
#    "name": "Biz Social Webdesign / Web Design by Jenn",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "115395771827453"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Media Webster",
#    "id": "416689008392125"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "WeBaloch - First Balochi Social Network",
#    "id": "310645388963015"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "192119584190796",
#      "name": "Event"
#     },
#     {
#      "id": "108470879231339",
#      "name": "Research Service"
#     }
#    ],
#    "id": "147895125402338"
#   },
#   {
#    "category": "Professional services",
#    "name": "Local Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "292125494205150"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Real Estate",
#    "id": "164269200441810"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Adapting Social Web Design & Digital Marketing",
#    "id": "232898900191494"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Meta Social Web",
#    "id": "117185225027930"
#   },
#   {
#    "category": "Business services",
#    "name": "LS Social Web",
#    "id": "515092701968229"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "SociablWeb - Social Media News, SEO Tips",
#    "id": "446376028729715"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Gimme Social Web",
#    "id": "190870261096138"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "G&B Marketing | Web & Social Media",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "331604230252618"
#   },
#   {
#    "category": "Product/service",
#    "name": "Mr Webinators |  Social Media Professional | Wahooligan's Wall",
#    "category_list": [
#     {
#      "id": "2201",
#      "name": "Product/Service"
#     }
#    ],
#    "id": "317645416802"
#   },
#   {
#    "category": "Personal website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE",
#    "id": "114852928532072"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Ecosystem",
#    "id": "186923664693877"
#   },
#   {
#    "category": "Professional services",
#    "name": "Free Social Media Webinars",
#    "id": "1388018764754564"
#   },
#   {
#    "category": "Local business",
#    "name": "Dot Ingenuity Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "131570646875176"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialEnterpriseWebsites.com",
#    "id": "208744325821683"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Digital For Dummies | Social, Web & other Technical Stuff",
#    "id": "476313985731653"
#   },
#   {
#    "category": "Website",
#    "name": "Web Social Tourism",
#    "id": "301608313292038"
#   },
#   {
#    "category": "Website",
#    "name": "SocialWebLike",
#    "id": "101946616632016"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web CT",
#    "id": "133897929978754"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Communication",
#    "id": "712032982208651"
#   },
#   {
#    "category": "Small business",
#    "name": "Ignite Social Web",
#    "id": "124131750957589"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "webfeuer - Social Media und mehr!",
#    "id": "369613539636"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Q and A",
#    "id": "433133770070530"
#   },
#   {
#    "category": "Personal website",
#    "name": "V Crown Social website",
#    "id": "509251595812044"
#   },
#   {
#    "category": "Education",
#    "name": "Lauren Webb - A Social Studies Life",
#    "category_list": [
#     {
#      "id": "108557642554592",
#      "name": "Educational Service"
#     }
#    ],
#    "id": "500943803329283"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web & Social Media Pundit: Consultancy & Management Services",
#    "id": "107316135994400"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Mobile Social Web Consulting",
#    "id": "323337601029865"
#   },
#   {
#    "category": "Community",
#    "name": "Web social life",
#    "id": "209254342562410"
#   },
#   {
#    "category": "Local business",
#    "name": "eitbits Webs & Social Media",
#    "id": "132214966858612"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "107061159384322"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Jenna McWatters - Web Design and Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "1416729695251458"
#   },
#   {
#    "category": "App page",
#    "name": "Web Social Mania",
#    "id": "445746788774576"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Media Websites",
#    "id": "121361064703333"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Web Media",
#    "id": "198866480158068"
#   },
#   {
#    "category": "Company",
#    "name": "Enova4U Dise\u00f1o Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "218721764817225"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Dreams: Web Series",
#    "id": "612698088813986"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SEO Workers - Forensic SEO & Social Semantic Web Consulting",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "22362057425"
#   },
#   {
#    "category": "Community",
#    "name": "ITE College Central - Social Media & Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "120366748050821"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Real-time Social Web",
#    "id": "121363354543881"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webius",
#    "category_list": [
#     {
#      "id": "177721448951559",
#      "name": "Workplace & Office"
#     }
#    ],
#    "id": "353444191416919"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "Social Web Games",
#    "id": "303818923034509"
#   },
#   {
#    "category": "Professional services",
#    "name": "Visibly Connected - Web Design, Social Media Manager, & SEO",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "190805541029564"
#   },
#   {
#    "category": "Telecommunication",
#    "name": "Entire Web - Social Network",
#    "id": "280834978742184"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "125310277520246"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Week Connecticut",
#    "id": "128455980522180"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Web Social Palmares",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "267515243361878"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Jasa Buat Web Social Media",
#    "id": "299273933600876"
#   },
#   {
#    "category": "Internet/software",
#    "name": "WebKit - Social Networks, E-commerce, Web Development",
#    "id": "96394316810"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "The Social Media Web Genie",
#    "id": "537321239622767"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "East West Websites & Social Media",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "258436910980966"
#   },
#   {
#    "category": "Community",
#    "name": "WebSocial",
#    "id": "787573591283803"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Leads",
#    "id": "118076131540902"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Palm Springs TRU Websites/Social Media",
#    "id": "1454453034787354"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Traffic & Social Networking",
#    "id": "159898507447542"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Qweboo \"Control Your Social Web\"",
#    "id": "146142715411167"
#   },
#   {
#    "category": "Society/culture website",
#    "name": "Wedding Social Networking, Free Wedding Websites",
#    "id": "187276274416"
#   },
#   {
#    "category": "Website",
#    "name": "Webverts Social Coupons",
#    "id": "290755324388883"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SeashoreWeb Social Media Marketing",
#    "id": "106838049410541"
#   },
#   {
#    "category": "News/media website",
#    "name": "SocialWebSeries",
#    "id": "245057172212562"
#   },
#   {
#    "category": "Company",
#    "name": "Sweden Social Web Camp",
#    "id": "290284817827"
#   },
#   {
#    "category": "Teens/kids website",
#    "name": "Web Social",
#    "id": "439935936081318"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Emma Fern\u00e1ndez \u00b7SEO \u00b7 Web \u00b7Social Media",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "658425767604330"
#   },
#   {
#    "category": "Business services",
#    "name": "Boxless Media - Social Media & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "150063728530867"
#   },
#   {
#    "category": "Professional services",
#    "name": "Widows Web Tattoo & Social Club",
#    "category_list": [
#     {
#      "id": "196188420407122",
#      "name": "Tattoo & Piercing"
#     }
#    ],
#    "id": "1508522469377417"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web Blog",
#    "id": "120064018007609"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web",
#    "id": "456664834354636"
#   },
#   {
#    "category": "Website",
#    "name": "Social Media Webinar",
#    "id": "119970001420128"
#   },
#   {
#    "category": "Professional services",
#    "name": "Ace Website And Social Media",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "437870413024484"
#   },
#   {
#    "category": "Retail and consumer merchandise",
#    "name": "Social Network Webshop",
#    "id": "424002204310411"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media Webinarcamps",
#    "id": "508178575883032"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Grafdom - Web Design & Social Media",
#    "id": "190124415513"
#   },
#   {
#    "category": "Company",
#    "name": "Fuzzbox Designs Limited - Web, Graphics, Social Media",
#    "id": "348306219052"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Web&Social Life - Italy",
#    "id": "162181413905627"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Media On The Web",
#    "id": "155217227871015"
#   },
#   {
#    "category": "Personal website",
#    "name": "My Friends Book ~ Social Networking Website",
#    "id": "249459055096850"
#   },
#   {
#    "category": "Professional services",
#    "name": "Charlie Website - Websites & Social Media",
#    "id": "200127703332354"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web2social",
#    "id": "127415450642739"
#   },
#   {
#    "category": "Website",
#    "name": "Mike Mueller: Marketing, Web Design, & Social Media Consultation",
#    "id": "50818804012"
#   },
#   {
#    "category": "Legal/law",
#    "name": "SWA Social Web Avvvocati & Webnews Giuridiche",
#    "id": "472013526210740"
#   },
#   {
#    "category": "Community organization",
#    "name": "Go Long Island - The Social Website for Long Island",
#    "id": "118029078273421"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Katink web design & social media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "400114793423652"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Web Social Marketing",
#    "id": "161192167329576"
#   },
#   {
#    "category": "App page",
#    "name": "Social Web to Print",
#    "id": "309361589082975"
#   },
#   {
#    "category": "Movie theater",
#    "name": "Webear.ning.com",
#    "id": "201297245816"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "iSocialWeb",
#    "id": "462294513847158"
#   },
#   {
#    "category": "Company",
#    "name": "Social Web",
#    "id": "1396212420669170"
#   },
#   {
#    "category": "Product/service",
#    "name": "@webdesignleads - Web Design & Development Social Leads",
#    "id": "162899293739458"
#   },
#   {
#    "category": "Transport/freight",
#    "name": "Ezymove - NZ Social Freight Website",
#    "id": "149753265216860"
#   },
#   {
#    "category": "Community",
#    "name": "Consulente Web Social Marketing",
#    "id": "1569815356573979"
#   },
#   {
#    "category": "Local business",
#    "name": "Barclay Jones - Recruitment Technology and Social Media",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "104235069630517"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Website",
#    "id": "1409211522669854"
#   },
#   {
#    "category": "Company",
#    "name": "Social Webfashion",
#    "id": "476630749055988"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Web-social.marketing",
#    "id": "1469299413303540"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Dashboard Professional and Tech: Web Development",
#    "id": "884698041558064"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social Web Brasil",
#    "id": "363231467061867"
#   },
#   {
#    "category": "Community",
#    "name": "Social web lead dakar commune biscuiterie",
#    "id": "557707754330768"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Buzz Websites",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "195634827182774"
#   },
#   {
#    "category": "Professional services",
#    "name": "ISocial Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "691387304273877"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "Sarah Webster Fabio Center for Social Justice",
#    "category_list": [
#     {
#      "id": "2603",
#      "name": "Non-Profit Organization"
#     }
#    ],
#    "id": "662567650459545"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "TAG - Social Web Radio",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ],
#    "id": "226795074081704"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "SocialWebCoding",
#    "id": "155266187877368"
#   },
#   {
#    "category": "Business services",
#    "name": "Monea Social Web Marketing",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "576009755850788"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web On",
#    "id": "677631292344242"
#   },
#   {
#    "category": "Education",
#    "name": "Web 214 Social Media",
#    "id": "1465751880343342"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "iptaque, web social, formation",
#    "id": "241894749184616"
#   },
#   {
#    "category": "Company",
#    "name": "Social Semantic Web",
#    "id": "36575011414"
#   },
#   {
#    "category": "Personal blog",
#    "name": "Lise Elder Web Design/Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "490355501021792"
#   },
#   {
#    "category": "News/media website",
#    "name": "The Church Of Nigeria: Anglican Communion - Akure Diocese (Social Webpage)",
#    "id": "143748352345882"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social Business",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "620197398021531"
#   },
#   {
#    "category": "Community",
#    "name": "Web COmmunities for Statistics for Social Innovation",
#    "id": "1398644970370772"
#   },
#   {
#    "category": "Software",
#    "name": "Socialspy Social Website Marketing Software",
#    "id": "468155203305128"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "DEGRAFIK - Social Media and Website Management",
#    "id": "113648292011480"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Webs99",
#    "id": "729800637066970"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Webmates",
#    "id": "474170526056354"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webunet - author of \"SEO & Social Media Marketing Guide\"",
#    "id": "355523558807"
#   },
#   {
#    "category": "App page",
#    "name": "Social Media Marketing using FB Websites",
#    "id": "472727666074315"
#   },
#   {
#    "category": "Book",
#    "name": "PR im Social Web",
#    "id": "161347393888030"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Act",
#    "id": "583432211721362"
#   },
#   {
#    "category": "Work position",
#    "name": "Social Media/Webb",
#    "id": "1488589091395050"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "502604446522710"
#   },
#   {
#    "category": "Website",
#    "name": "SocialProofWeb",
#    "id": "475543625793316"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Marketing/Web expert",
#    "id": "363931623705636"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ICTIP - Online Marketing, Social Media Management and Web Development",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "147188657823"
#   },
#   {
#    "category": "Book",
#    "name": "Texten f\u00fcrs Social Web",
#    "id": "163775863785154"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Marketing & Webdesign Services",
#    "id": "89608325880"
#   },
#   {
#    "category": "Small business",
#    "name": "glenroyDAVIE Signs | Web | Social Media | Print",
#    "id": "144654462241199"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web TV. We socialize your passion",
#    "id": "285679378241848"
#   },
#   {
#    "category": "Company",
#    "name": "Web Infotech Solutions",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "400241243372561"
#   },
#   {
#    "category": "Cause",
#    "name": "My Social Website",
#    "id": "791021540948043"
#   },
#   {
#    "category": "Health/beauty",
#    "name": "Annette Webster - Social Entrepreneur",
#    "id": "653669544643897"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Colab: pr + social + web",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "161237563917230"
#   },
#   {
#    "category": "Software",
#    "name": "Fimark's Family Reunion Planner Social Web App",
#    "id": "119054884844075"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webs",
#    "id": "678244902251294"
#   },
#   {
#    "category": "Product/service",
#    "name": "Eguino Social Web",
#    "id": "114206991977394"
#   },
#   {
#    "category": "Professional services",
#    "name": "SocialMedia webmarketing School",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "624821100963943"
#   },
#   {
#    "category": "Book",
#    "name": "Kundenservice im Social Web",
#    "id": "244611275577666"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Shares",
#    "id": "666423320041020"
#   },
#   {
#    "category": "Local business",
#    "name": "RamCage Social Web Portals",
#    "id": "121168127989143"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cloud",
#    "id": "361274951376"
#   },
#   {
#    "category": "News/media website",
#    "name": "Social Web Content",
#    "id": "293898797278"
#   },
#   {
#    "category": "Website",
#    "name": "Social Boost",
#    "id": "701926083195478"
#   },
#   {
#    "category": "Software",
#    "name": "Web and social media traffic bundles",
#    "id": "659364417455948"
#   },
#   {
#    "category": "Personal website",
#    "name": "Social Web Monitoring",
#    "id": "111019338966579"
#   },
#   {
#    "category": "Community",
#    "name": "Marci Rosenblum - Expert SEO Specialist, Web Traffic, Social Media Marketer",
#    "id": "70863093045"
#   },
#   {
#    "category": "Company",
#    "name": "Digital Domain - Website & Social Media Specialists",
#    "id": "357741767651125"
#   },
#   {
#    "category": "Internet/software",
#    "name": "FUA Social Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "1410567895848855"
#   },
#   {
#    "category": "News/media website",
#    "name": "Advertising on the Web",
#    "id": "28705232393"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Artwhere Mobile Social Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "46316179114"
#   },
#   {
#    "category": "Company",
#    "name": "More Cabbage Social PR, Branding, & Websites",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "216734806323"
#   },
#   {
#    "category": "Local business",
#    "name": "MerlinFX Web Email Marketing Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ],
#    "id": "139004380018"
#   },
#   {
#    "category": "Website",
#    "name": "WebCamSocial.com",
#    "id": "193570570659564"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "End of Line Magazine - Social, web, dev",
#    "id": "173676026024784"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Webdesign",
#    "id": "220350687983200"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Anxiety - A Web Series",
#    "id": "107080656067158"
#   },
#   {
#    "category": "University",
#    "name": "Master Universitario in \"Web communication & social media\"",
#    "category_list": [
#     {
#      "id": "108051929285833",
#      "name": "College & University"
#     }
#    ],
#    "id": "291350937559881"
#   },
#   {
#    "category": "Product/service",
#    "name": "Webmeister Social SEO",
#    "id": "653130718079993"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "Second Wednesday - Web industry social events",
#    "id": "83659087689"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Presto Web Design & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "199019100182074"
#   },
#   {
#    "category": "Entertainment website",
#    "name": "V Crown Social website.",
#    "id": "715273168500573"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Manager Web",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "339197272789256"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "FB Social Web",
#    "id": "214276165260728"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webdesign, Social Media and Online-Marketing for Real Estate Projects",
#    "category_list": [
#     {
#      "id": "198327773511962",
#      "name": "Real Estate"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "151733308230709"
#   },
#   {
#    "category": "Local business",
#    "name": "Quisk Design - Websites, Branding & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "328671177050"
#   },
#   {
#    "category": "Community",
#    "name": "Weblogmine - The Social",
#    "id": "552742824756805"
#   },
#   {
#    "category": "Business services",
#    "name": "L'Operosa Social Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "259629940911495"
#   },
#   {
#    "category": "Website",
#    "name": "PickMe Web - Online Social Bookmarking",
#    "id": "116207408393755"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Diana Wilkins - Websites and Internet Marketing Services",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
# ...
#    "name": "ITE College West - Nitec in Social Media and Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "162257397196866"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Media Marketing and Website Design Agency",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ],
#    "id": "129701130375873"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "ARMO PS - Social Marketing & Webs",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "259193520907269"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Web Academy",
#    "id": "133517650020227"
#   },
#   {
#    "category": "Community",
#    "name": "WebdDee Social Community",
#    "id": "134952703245683"
#   },
#   {
#    "category": "Product/service",
#    "name": "Designs by Desiree Business Solutions",
#    "id": "436943043033766"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Social Pelican Web Services",
#    "id": "446747078697655"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Marketing & Web Communication",
#    "id": "101249566673888"
#   },
#   {
#    "category": "Website",
#    "name": "ABDLmatch.com - Your ABDL Dating & Social Network Website",
#    "id": "156913127790511"
#   },
#   {
#    "category": "Local business",
#    "name": "SocialExecs | Social Media & Web Specialists",
#    "id": "105478339515932"
#   },
#   {
#    "category": "Book",
#    "name": "Empfehlungsmarketing im Social Web - Das Buch",
#    "id": "343063572502618"
#   },
#   {
#    "category": "Education",
#    "name": "Web ENSFLLA Social",
#    "id": "218781014813739"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Likefollower.it - Social & Web Marketing",
#    "id": "493833740703153"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Jayu Web Design & Social Media",
#    "id": "683295505094900"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Orange Matter Digital Media Web Development and Social Media Optimisation",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "166899174032"
#   },
#   {
#    "category": "Website",
#    "name": "FollowBud Social Network Website",
#    "id": "713861428691596"
#   },
#   {
#    "category": "Product/service",
#    "name": "Corso di Web Marketing e Social Media Marketing",
#    "id": "479928852108996"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Media Branding Services/Website Services",
#    "id": "1517835035125112"
#   },
#   {
#    "category": "Business services",
#    "name": "Tentler - Social Web Consulting & Marketing.",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "315287605293162"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media App Design - Brand Web Direct",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "180204945400699"
#   },
#   {
#    "category": "Website",
#    "name": "Latin Web Social",
#    "id": "144860758877785"
#   },
#   {
#    "category": "Organization",
#    "name": "NYSC  OYO Social Web",
#    "id": "1439946206246362"
#   },
#   {
#    "category": "Local business",
#    "name": "Onefoursix - Specialists in Design, Print, Social Media, and Websites.",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "197888373555475",
#      "name": "Printing Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "453613371345754"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Massick Media & Design | Graphic / Web / Social Media Design",
#    "id": "128138577262750"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialMedia Designs",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "173876899342866"
#   },
#   {
#    "category": "Community",
#    "name": "YL WebStudio",
#    "id": "381407298588705"
#   },
#   {
#    "category": "Internet/software",
#    "name": "B7Web Social Marketing",
#    "id": "295801747182578"
#   },
#   {
#    "category": "Tv show",
#    "name": "Social Net Club Emission 100% WEB 100 %LYON",
#    "id": "230243223809910"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Labs - Social Media Team",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "1378760945677870"
#   },
#   {
#    "category": "Business person",
#    "name": "Paul Haley - Web Design and Social Media",
#    "id": "229853217188491"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media - \u039a\u03bf\u03b9\u03bd\u03c9\u03bd\u03b9\u03ba\u03ac \u0394\u03af\u03ba\u03c4\u03c5\u03b1",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "150944928251073"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Whitedrop  Web Marketing Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "681921881866837"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialTechnia, marketing for the social web",
#    "id": "123400527718504"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Esther Szczerba - Web & Marketing Solutions, Social Media",
#    "id": "272044382898925"
#   },
#   {
#    "category": "University",
#    "name": "Social Media and Web Technologies",
#    "id": "273616712747412"
#   },
#   {
#    "category": "Product/service",
#    "name": "WebMarketingSocialMedia",
#    "id": "451601061534690"
#   },
#   {
#    "category": "Interest",
#    "name": "Social Semantic Web",
#    "id": "103989939638996"
#   },
#   {
#    "category": "Musical instrument",
#    "name": "Wesome Web & Social Media solutions",
#    "id": "461405120593275"
#   },
#   {
#    "category": "Company",
#    "name": "SW Social Web",
#    "id": "209972042367716"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Zelcovia.web.social",
#    "id": "1475015116103908"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Advertwork - Website & Social Media Marketing",
#    "id": "470543823055800"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Marketing - Your Website Inside FB",
#    "id": "467525046604604"
#   },
#   {
#    "category": "Local business",
#    "name": "Media Villages - Mobile Responsive Social Media Centric Web Design.",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "153165781376857"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Gulf Coast Social Media & Web Design",
#    "id": "280769368741562"
#   },
#   {
#    "category": "Organization",
#    "name": "SowSkills - Social-Web-Skills for eldery people",
#    "id": "225477664142196"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Fletcher Web Marketing | SEO | SEM | Social Media | Analytics",
#    "id": "339797189378903"
#   },
#   {
#    "category": "Interest",
#    "name": "Web social",
#    "id": "726519714039235"
#   },
#   {
#    "category": "Company",
#    "name": "Wesome Web & Social Media solutions",
#    "id": "540823335945236"
#   },
#   {
#    "category": "Church/religious organization",
#    "name": "Kirche im Web 2.0 / Social Media",
#    "id": "161519650568794"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Digital Marketing, Social Media, Mobile Marketing and Web 3.0 is 10 Edge",
#    "id": "141835972508234"
#   },
#   {
#    "category": "Website",
#    "name": "vGal Website Content Writing, Social Media & Solutions",
#    "id": "120224928014658"
#   },
#   {
#    "category": "Business services",
#    "name": "Imagination Marketing - SEO Website Marketing Social Media Management",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "453192678092536"
#   },
#   {
#    "category": "Website",
#    "name": "WebSocial.ly",
#    "id": "113759552036905"
#   },
#   {
#    "category": "Product/service",
#    "name": "Basic Social Media & Web Content Consulting",
#    "id": "176180415757198"
#   },
#   {
#    "category": "Community",
#    "name": "Social Media Webinars and Seminars",
#    "id": "640189532715173"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Consulting Test Page",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "159918207405302"
#   },
#   {
#    "category": "Work position",
#    "name": "Social Web Writer",
#    "id": "1504493076485620"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Logion Web Design - Internet and Social Media Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "149092381793435"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Bonobo - Web & Social Media",
#    "id": "185366164983180"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Media & Web Video Marketing",
#    "id": "170178356353402"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Bridge The Gap Website Design & Social Media Management",
#    "id": "1466836533576704"
#   },
#   {
#    "category": "Professional services",
#    "name": "SEO Sophie Websites & Social Marketing",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "334358073324467"
#   },
#   {
#    "category": "Professional services",
#    "name": "Web Marketing & Social Media - Alessia Scomparin",
#    "id": "244498258987043"
#   },
#   {
#    "category": "Internet/software",
#    "name": "APclick - social media marketing e web writing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "171645079640594"
#   },
#   {
#    "category": "Professional services",
#    "name": "Studio Castelli - Comunicazione, grafica, web, social strategies",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "179814955402116"
#   },
#   {
#    "category": "Local business",
#    "name": "Global Vision Web &  Social Media Company",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "143631244740"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Super Socialites| Web Design-Social Media & Marketing",
#    "id": "128655320529070"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Conceptz",
#    "id": "573667922645222"
#   },
#   {
#    "category": "Education",
#    "name": "Master in Social Media e Web Community Manager",
#    "category_list": [
#     {
#      "id": "186998168001766",
#      "name": "Private School"
#     }
#    ],
#    "id": "298574890156815"
#   },
#   {
#    "category": "Local business",
#    "name": "Dise\u00f1o Web y Social Media",
#    "id": "389293934485009"
#   },
#   {
#    "category": "Website",
#    "name": "Men Meen Men Gay Social Networking Website",
#    "category_list": [
#     {
#      "id": "2202",
#      "name": "Website"
#     }
#    ],
#    "id": "324723351781"
#   },
#   {
#    "category": "Local business",
#    "name": "~ SocialFly ~ Dise\u00f1o Web 2.0",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "317064404977552"
#   },
#   {
#    "category": "Community",
#    "name": "Rede social web",
#    "id": "619925711413269"
#   },
#   {
#    "category": "Community",
#    "name": "Webishark Earn Money Using This Social Media.",
#    "id": "546541905458135"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Complete Dreams Design - Web, Social, Graphic, and Video Design",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "119846254710406"
#   },
#   {
#    "category": "Radio station",
#    "name": "Lina Web Radio Social",
#    "id": "243771532452812"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "RK Image :: Video, Web, Photo, Social Media",
#    "id": "153823274652343"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Ujobber Web + Print + Social",
#    "id": "106775612711545"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Sikuro Web & Web Social Marketing",
#    "id": "116990318484769"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Shlomo Walt's Creative Website Writing and Social Media Services",
#    "id": "369153603178816"
#   },
#   {
#    "category": "Business person",
#    "name": "Web & Social Media Strategist Jani Sj\u00f6lund",
#    "id": "301865433210142"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Marketing Social Web",
#    "id": "317803944941323"
#   },
#   {
#    "category": "Business services",
#    "name": "Ca2 Solution - Social, Graphic & Web Advertising",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "443121155714852"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Webgewandt SEO Berlin & Social Media",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "233930279953768"
#   },
#   {
#    "category": "Book",
#    "name": "Personalsuche im Social Web",
#    "id": "202329819852360"
#   },
#   {
#    "category": "Business services",
#    "name": "Bali Web Pro | Social Media & Internet Consulting",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "289883247792688"
#   },
#   {
#    "category": "Website",
#    "name": "Matlim Social Networking Chat Website",
#    "id": "179064625564293"
#   },
#   {
#    "category": "Personal website",
#    "name": "Tchat webcam social",
#    "id": "234440059921976"
#   },
#   {
#    "category": "Community",
#    "name": "LBGT world social website.",
#    "id": "241742762545993"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "Expert Social Media Campaigns and Website Design",
#    "id": "674659739267041"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Dezignscene NZ Web Design, Mobile & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "278249875623326"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Instus - Social Media & Web Based Services",
#    "id": "462458733874919"
#   },
#   {
#    "category": "News/media website",
#    "name": "Argentina Noticias.Web",
#    "id": "192076660835226"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
mtsw_id = '146803958708175'
pp(g.get_object(mtsw_id))

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print "Pepsi likes:", int_format(g.get_object(pepsi_id)['likes'])
print "Coke likes:", int_format(g.get_object(coke_id)['likes'])

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pp(g.get_connections(pepsi_id, 'feed'))
pp(g.get_connections(pepsi_id, 'links'))

pp(g.get_connections(coke_id, 'feed'))
pp(g.get_connections(coke_id, 'links'))

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "friends")['data']

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print likes

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print 'Top 10 likes amongst friends'
print pt

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print "Top 10 like categories for friends"
print pt

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print "Number of likes per friend"
print pt

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print "My likes"
print pt

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print
print "My common likes with friends"
print pt

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print "My similar friends (ranked)"
print pt

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist(ranked_friends.values())
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...

plt.figure() # Display the previous plot
plt.hist(ranked_friends.values(),
          bins=arange(1,max(ranked_friends.values()),1))
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    print friend_id
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
print nxg

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = max(clique_sizes)
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print 'Num cliques:', num_cliques
print 'Avg clique size:', avg_clique_size
print 'Max clique size:', max_clique_size
print 'Num max cliques:', num_max_cliques
print
print 'Friends in all max cliques:'
print json.dumps(friends_in_all_max_cliques, indent=1)
print
print 'Max cliques:'
print json.dumps(max_cliques, indent=1)

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
